# %%
import stacja.main

# %%
stacja.main.command_line_create_osoba()
# Out:
# Id:  9
# Imie:  Pawel
# Nazwisko:  Testowy
# Email:  pawel.testowy@test.pl
# Dodano osobe

# %%
stacja.main.command_line_example_data()

# %%
stacja.main.command_line_export_to_csv()

# %%
import remote.client

# %%
remote.client.create_tables()

# %%
remote.client.import_data_to_postgres()
# Out:
# ['9', 'Pawel', 'Testowy', 'pawel.testowy@test.pl']
# ['1', 'Jan', 'Kowalski', 'jan.kowalski@gmail.com']
# ['2', 'Adam', 'Nowak', 'adam.nowak@gmail.com']
# ['3', 'Anna', 'Kowalska', 'anna.kowalski@gmail.com']
# ['4', 'Jan', 'Nowak', 'jan.nowak@gmail.com']

# %%
import remote.raport

# %%
remote.raport.generate_charts('21.06.2023', '24.06.2023')

# %%
import remote.raport

# %%
remote.raport.generate_charts('21.06.2023', '25.06.2023')
